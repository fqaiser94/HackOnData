# %% [markdown]
# ##Week 2 - Module One

# %% [markdown]
# ### Lecture: Big Data, Hardware Trends, and Apache Spark
# Based on https://docs.cloud.databricks.com/docs/latest/courses/Introduction%20to%20Big%20Data%20with%20Apache%20Spark%20(CS100-1x)/Module%202:%20Lectures.html

# %%
displayHTML('https://www.youtube.com/embed/FNKibDg5TOM')

# %%
displayHTML('https://youtube.com/embed/0JdJe5iehhw')

# %%
displayHTML('https://youtube.com/embed/KmIIMdsXGzc')

# %%
displayHTML('https://youtube.com/embed/Euk1v3VtNcM')

# %%
displayHTML('https://youtube.com/embed/2avolYzgxUw')

# %%
displayHTML('https://youtube.com/embed/j101-LMBXZI')

# %%
displayHTML('https://youtube.com/embed/NaHNsPEK3KA')

# %%
displayHTML('https://youtube.com/embed/NqG_hYAKjYk')

# %%
displayHTML('https://youtube.com/embed/vat5Jki1lbI')

# %%
displayHTML('https://youtube.com/embed/-PnDApChyZc')

# %%
displayHTML('https://youtube.com/embed/Ddq3Gua2QFg')

# %% [markdown]
# ### Lecture 4: Spark Essentials

# %%
displayHTML('https://youtube.com/embed/ACdKvNhd2vk')

# %%
displayHTML('https://youtube.com/embed/Ia-ktejXeYk')

# %%
displayHTML('https://youtube.com/embed/3nreQ1N7Jvk')

# %%
displayHTML('https://youtube.com/embed/gyCrxvTzbXU')

# %%
displayHTML('https://youtube.com/embed/360UHWy052k')

# %%
displayHTML('https://youtube.com/embed/r9Px_rBxACw')

# %%
displayHTML('https://youtube.com/embed/2XHwAFcp6w4')

# %%
displayHTML('https://youtube.com/embed/F2G4Wbc5ZWQ')

# %%
displayHTML('https://youtube.com/embed/VU0LrzjTQZ0')

# %%
displayHTML('https://youtube.com/embed/sRRTIJ6uzTE')

# %%
displayHTML('https://youtube.com/embed/HWZUqNYAJj4')

# %%
displayHTML('https://youtube.com/embed/uEiaqdCpeUc')

# %%
displayHTML('https://youtube.com/embed/I9Zcr4R35Ao')

# %%
displayHTML('https://youtube.com/embed/rUE8xMhy2Ms')

# %%
displayHTML('https://youtube.com/embed/_YjhA1A_rHU')

# %%
displayHTML('https://youtube.com/embed/F50Vty9Ia8Y')
