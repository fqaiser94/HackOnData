# %% [markdown]
# ## Module Eight Lecture

# %% [markdown]
# ### Principal Component Analysis and Neuroimaging

# %%
displayHTML('https://youtube.com/embed/ws035CVtMeg')

# %%
displayHTML('https://youtube.com/embed/z3cU04LobEs')

# %%
displayHTML('https://youtube.com/embed/XsP0FPgTEqs')

# %%
displayHTML('https://youtube.com/embed/lzI84w3Mots')

# %%
displayHTML('https://youtube.com/embed/JM5Qa2DaOxA')

# %%
displayHTML('https://youtube.com/embed/r9gLQTWTGlA')

# %%
displayHTML('https://youtube.com/embed/n448xt1qduU')

# %%
displayHTML('https://youtube.com/embed/orHoYFyT-y8')

# %%
displayHTML('https://youtube.com/embed/RWebrpNTKT0')
