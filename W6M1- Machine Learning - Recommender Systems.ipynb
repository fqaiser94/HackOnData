# %% [markdown]
# ## Module Six - Lecture

# %% [markdown]
# ### Matrix factorizations for recommendations
#
# ##### HackOnData.com Workshops

# %%
displayHTML('https://www.youtube.com/embed/aKQfUbxU96c')

# %%
displayHTML('https://www.youtube.com/embed/Q0VXllYilM0?t=419')
