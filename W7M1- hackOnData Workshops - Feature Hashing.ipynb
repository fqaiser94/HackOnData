# %% [markdown]
# ## Module Seven Lecture

# %% [markdown]
# ### Lecture 7: Logistic Regression and Click-through Rate Prediction

# %%
displayHTML('https://youtube.com/embed/D8aQrFnRrgU')

# %%
displayHTML('https://youtube.com/embed/gqV5Lw1FaRU')

# %%
displayHTML('https://youtube.com/embed/qAr6QGDFghw')

# %%
displayHTML('https://youtube.com/embed/j1fSgLjyEaQ')

# %%
displayHTML('https://youtube.com/embed/HM5wmuUCcV4')

# %%
displayHTML('https://youtube.com/embed/zFKS7PA060w')

# %%
displayHTML('https://youtube.com/embed/0N2OGWoYzq4')

# %%
displayHTML('https://youtube.com/embed/9m9Rkw0cVDA')
