# %% [markdown]
# ## Module Four Lecture - HackOnData.com
#
# Based on the EdX Course by DataBricks -- Big Data Analysis with Apache Spark

# %% [markdown]
# ### Lecture 7: Data Quality

# %%
displayHTML('https://youtube.com/embed/ZmykGDdTX40')

# %%
displayHTML('https://youtube.com/embed/s7iP0Mkp6qY')

# %%
displayHTML('https://youtube.com/embed/4rD6aX2xBcQ')

# %%
displayHTML('https://youtube.com/embed/Ht4FROodF_s')

# %%
displayHTML('https://youtube.com/embed/3INREmKfGYM')

# %%
displayHTML('https://youtube.com/embed/iUCzeRTPb2Q')

# %%
displayHTML('https://youtube.com/embed/5_j1F8drIgE')

# %%
displayHTML('https://youtube.com/embed/uNf1SVu589M')

# %%
displayHTML('https://youtube.com/embed/is_galeNA88')

# %%
displayHTML('https://youtube.com/embed/9FxGgDtj_Yg')

# %%
displayHTML('https://youtube.com/embed/BM4IBS2tDP8')

# %%
displayHTML('https://youtube.com/embed/yDpXe1zno2U')

# %%
displayHTML('https://youtube.com/embed/iifUiQ-CziE')
