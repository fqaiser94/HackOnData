# %% [markdown]
# ## Module File Lecture
#
# HackOnData.com workshops

# %% [markdown]
# ### Lecture 1: Course Overview and Introduction to Machine Learning

# %%
displayHTML('https://youtube.com/embed/M5poFRMygGY')

# %%
displayHTML('https://youtube.com/embed/fUTDfkhcY44')

# %%
displayHTML('https://youtube.com/embed/NJZht7aV2NQ')

# %%
displayHTML('https://youtube.com/embed/XPxOL1--GXo')

# %%
displayHTML('https://youtube.com/embed/Q7hxwkG9hNE')

# %%
fasdfasdfasdfasdf

# %%
displayHTML('https://youtube.com/embed/mnS0lJncJzw')

# %%
displayHTML('https://youtube.com/embed/Riuee7qxdX4')

# %%
displayHTML('https://youtube.com/embed/OednhGRp938')
